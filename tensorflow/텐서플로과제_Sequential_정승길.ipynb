# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.boston_housing.load_data(
    path='boston_housing.npz', test_split=0.2, seed=113
)

print(x_train.shape) #열이 몇개

model = tf.keras.Sequential([])
model.add(tf.keras.layers.Dense(units=1, input_dim=13))

model.summary()
model.compile(loss='mse', optimizer='adam')
record = model.fit(x_train, y_train, epochs=100, batch_size=10, verbose=2)


loss = record.history['loss']
print("loss:", loss[-1])
print("weights:", model.layers[0].weights[0].numpy())
print("bias:", model.layers[0].weights[1].numpy())

plt.plot(loss)
plt.xlabel('epochs')
plt.ylabel('loss')
plt.show()
# Out:
# (404, 13)
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 1)                 14
#
# ...
# Total params: 14
# Trainable params: 14
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 41/41 - 0s - loss: 79117.7266 - 298ms/epoch - 7ms/step
# Epoch 2/100
# 41/41 - 0s - loss: 60462.3750 - 29ms/epoch - 707us/step
# Epoch 3/100
# 41/41 - 0s - loss: 45225.8281 - 28ms/epoch - 683us/step
# Epoch 4/100
# 41/41 - 0s - loss: 33251.3281 - 29ms/epoch - 707us/step
# Epoch 5/100
# 41/41 - 0s - loss: 23959.7324 - 28ms/epoch - 683us/step
# Epoch 6/100
# 41/41 - 0s - loss: 16953.4609 - 29ms/epoch - 707us/step
# Epoch 7/100
# 41/41 - 0s - loss: 11788.7627 - 27ms/epoch - 659us/step
# Epoch 8/100
# 41/41 - 0s - loss: 8072.1602 - 27ms/epoch - 659us/step
# Epoch 9/100
# ...
